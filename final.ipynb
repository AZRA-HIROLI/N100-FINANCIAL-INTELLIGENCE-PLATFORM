# %%
import os
import sys

deliverables = [
    ("D-01", "data/nifty100.db"),
    ("D-02", "output/load_audit.csv"),
    ("D-03", "output/validation_failures.csv"),
    ("D-04", "notebooks/exploratory_queries.sql"),
    ("D-05", "data/nifty100.db"),
    ("D-06", "output/capital_allocation.csv"),
    ("D-07", "output/screener_output.xlsx"),
    ("D-08", "config/screener_config.yaml"),
    ("D-09", "output/peer_comparison.xlsx"),
    ("D-10", "reports/radar_charts/"),
    ("D-11", "src/dashboard/app.py"),
    ("D-12", "output/valuation_summary.xlsx"),
    ("D-13", "output/cashflow_intelligence.xlsx"),
    ("D-14", "output/pros_cons_generated.csv"),
    ("D-15", "output/analysis_parsed.csv"),
    ("D-16", "reports/tearsheets/"),
    ("D-17", "reports/sector/"),
    ("D-18", "reports/portfolio/"),
    ("D-19", "output/cluster_labels.csv"),
    ("D-20", "src/api/main.py"),
    ("D-21", "reports/pytest_report.html"),
    ("D-22", "docs/analyst_guide.pdf"),
    ("D-23", "docs/acceptance_checklist.pdf")
]

print("=== Project Deliverables Final Audit ===")
missing_count = 0

for d_id, path in deliverables:
    exists = os.path.exists(path) or os.path.exists(path.rstrip("/"))
    status = "VERIFIED [OK]" if exists else "MISSING [X]"
    if not exists:
        missing_count += 1
    print(f"[{d_id}] {path} -> {status}")

print(f"\nAudit Summary: {len(deliverables) - missing_count}/{len(deliverables)} deliverables verified successfully.")

if missing_count == 0:
    print("\n>>> PROJECT SIGN-OFF APPROVED: All 23 deliverables completed successfully! <<<")
else:
    print(f"\n>>> Warning: {missing_count} deliverable paths require manual check. <<<")
# Out:
# === Project Deliverables Final Audit ===
# [D-01] data/nifty100.db -> MISSING [X]
# [D-02] output/load_audit.csv -> VERIFIED [OK]
# [D-03] output/validation_failures.csv -> VERIFIED [OK]
# [D-04] notebooks/exploratory_queries.sql -> MISSING [X]
# [D-05] data/nifty100.db -> MISSING [X]
# [D-06] output/capital_allocation.csv -> VERIFIED [OK]
# [D-07] output/screener_output.xlsx -> MISSING [X]
# [D-08] config/screener_config.yaml -> VERIFIED [OK]
# [D-09] output/peer_comparison.xlsx -> MISSING [X]
# [D-10] reports/radar_charts/ -> VERIFIED [OK]
# [D-11] src/dashboard/app.py -> VERIFIED [OK]
# [D-12] output/valuation_summary.xlsx -> MISSING [X]
# [D-13] output/cashflow_intelligence.xlsx -> VERIFIED [OK]
# [D-14] output/pros_cons_generated.csv -> VERIFIED [OK]
# [D-15] output/analysis_parsed.csv -> VERIFIED [OK]
# [D-16] reports/tearsheets/ -> VERIFIED [OK]
# [D-17] reports/sector/ -> VERIFIED [OK]
# [D-18] reports/portfolio/ -> VERIFIED [OK]
# ...
